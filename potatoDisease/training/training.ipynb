# %%
import tensorflow as tf
from tensorflow.keras import models, layers

import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Potato-Disease-DataSet",
    shuffle = True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
plt.figure(figsize = (10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.axis("off")
        plt.title(class_names[label_batch[i]])

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split = 0.1, test_split = 0.1,shuffle = True, shuffle_size = 1000):
        ds_size = len(ds)
        
        if shuffle:
            ds = ds.shuffle(shuffle_size,seed = 12)
        
        train_size = int(train_split*ds_size)
        val_size = int(val_split*ds_size)
        
        train_ds=ds.take(train_size)
        val_ds = ds.skip(train_size).take(val_size)
        test_ds = ds.skip(train_size).skip(val_size)
        
        return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, kernel_size = (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, kernel_size = (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),  
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(n_classes, activation = 'softmax')
])
model.build(input_shape = input_shape)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          9248
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 55,587
# Trainable params: 55,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data=val_ds
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 55s 1s/step - loss: 0.0154 - accuracy: 0.9954 - val_loss: 0.0189 - val_accuracy: 0.9948
# Epoch 2/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.0127 - val_accuracy: 0.9948
# Epoch 3/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0189 - accuracy: 0.9931 - val_loss: 0.0810 - val_accuracy: 0.9688
# Epoch 4/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.0772 - accuracy: 0.9693 - val_loss: 0.0782 - val_accuracy: 0.9688
# Epoch 5/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.0159 - val_accuracy: 0.9948
# Epoch 6/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0131 - accuracy: 0.9977 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 7/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0102 - val_accuracy: 0.9948
# Epoch 8/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.0562 - val_accuracy: 0.9792
# Epoch 9/50
# 54/54 [==============================] - 63s 1s/step - loss: 0.0086 - accuracy: 0.9988 - val_loss: 0.0074 - val_accuracy: 0.9948
# Epoch 10/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 11/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0272 - accuracy: 0.9902 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 12/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 13/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.0146 - val_accuracy: 0.9948
# Epoch 14/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0119 - val_accuracy: 0.9948
# Epoch 15/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0583 - val_accuracy: 0.9792
# Epoch 16/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0042 - accuracy: 0.9977 - val_loss: 0.0865 - val_accuracy: 0.9740
# Epoch 17/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0398 - accuracy: 0.9844 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 18/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0416 - accuracy: 0.9838 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 19/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 20/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 21/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 22/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0277 - val_accuracy: 0.9896
# Epoch 23/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0225 - val_accuracy: 0.9896
# Epoch 24/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0186 - accuracy: 0.9931 - val_loss: 0.0493 - val_accuracy: 0.9792
# Epoch 25/50
# 47/54 [=========================>....] - ETA: 7s - loss: 0.0818 - accuracy: 0.9734

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 3s 233ms/step - loss: 0.0620 - accuracy: 0.9766

# %%
scores
# Out:
# [0.06198703497648239, 0.9765625]

# %%
history

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), )
